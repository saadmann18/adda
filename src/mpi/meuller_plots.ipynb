# %%
import numpy as np
import pandas as pd

# %%
file = "mueller"

# %%
with open(file) as f:
    col_names = f.read().splitlines()[0].split()

# %%
with open('mueller') as f:
    ncols = len(f.readline().split(' ')) - 1
    data = np.fromiter((v for line in f for v in line.split(' ')[:-1]), float ,count=-1)
    cols = data.reshape(int(data.size / ncols), ncols).transpose()

# %%
col_names
# Out:
# ['theta',
#  's11',
#  's12',
#  's13',
#  's14',
#  's21',
#  's22',
#  's23',
#  's24',
#  's31',
#  's32',
#  's33',
#  's34',
#  's41',
#  's42',
#  's43',
#  's44']

# %%
len(col_names)
# Out:
# 17

# %%
cols[0]
# Out:
# array([  0. ,   0.5,   1. ,   1.5,   2. ,   2.5,   3. ,   3.5,   4. ,
#          4.5,   5. ,   5.5,   6. ,   6.5,   7. ,   7.5,   8. ,   8.5,
#          9. ,   9.5,  10. ,  10.5,  11. ,  11.5,  12. ,  12.5,  13. ,
#         13.5,  14. ,  14.5,  15. ,  15.5,  16. ,  16.5,  17. ,  17.5,
#         18. ,  18.5,  19. ,  19.5,  20. ,  20.5,  21. ,  21.5,  22. ,
#         22.5,  23. ,  23.5,  24. ,  24.5,  25. ,  25.5,  26. ,  26.5,
#         27. ,  27.5,  28. ,  28.5,  29. ,  29.5,  30. ,  30.5,  31. ,
#         31.5,  32. ,  32.5,  33. ,  33.5,  34. ,  34.5,  35. ,  35.5,
#         36. ,  36.5,  37. ,  37.5,  38. ,  38.5,  39. ,  39.5,  40. ,
#         40.5,  41. ,  41.5,  42. ,  42.5,  43. ,  43.5,  44. ,  44.5,
#         45. ,  45.5,  46. ,  46.5,  47. ,  47.5,  48. ,  48.5,  49. ,
#         49.5,  50. ,  50.5,  51. ,  51.5,  52. ,  52.5,  53. ,  53.5,
#         54. ,  54.5,  55. ,  55.5,  56. ,  56.5,  57. ,  57.5,  58. ,
#         58.5,  59. ,  59.5,  60. ,  60.5,  61. ,  61.5,  62. ,  62.5,
#         63. ,  63.5,  64. ,  64.5,  65. ,  65.5,  66. ,  66.5,  67. ,
#         67.5,  68. ,  68.5,  69. ,  69.5,  70. ,  70.5,  71. ,  71.5,
#         72. ,  72.5,  73. ,  73.5,  74. ,  74.5,  75. ,  75.5,  76. ,
#         76.5,  77. ,  77.5,  78. ,  78.5,  79. ,  79.5,  80. ,  80.5,
#         81. ,  81.5,  82. ,  82.5,  83. ,  83.5,  84. ,  84.5,  85. ,
#         85.5,  86. ,  86.5,  87. ,  87.5,  88. ,  88.5,  89. ,  89.5,
#         90. ,  90.5,  91. ,  91.5,  92. ,  92.5,  93. ,  93.5,  94. ,
#         94.5,  95. ,  95.5,  96. ,  96.5,  97. ,  97.5,  98. ,  98.5,
#         99. ,  99.5, 100. , 100.5, 101. , 101.5, 102. , 102.5, 103. ,
#        103.5, 104. , 104.5, 105. , 105.5, 106. , 106.5, 107. , 107.5,
#        108. , 108.5, 109. , 109.5, 110. , 110.5, 111. , 111.5, 112. ,
#        112.5, 113. , 113.5, 114. , 114.5, 115. , 115.5, 116. , 116.5,
#        117. , 117.5, 118. , 118.5, 119. , 119.5, 120. , 120.5, 121. ,
#        121.5, 122. , 122.5, 123. , 123.5, 124. , 124.5, 125. , 125.5,
#        126. , 126.5, 127. , 127.5, 128. , 128.5, 129. , 129.5, 130. ,
#        130.5, 131. , 131.5, 132. , 132.5, 133. , 133.5, 134. , 134.5,
#        135. , 135.5, 136. , 136.5, 137. , 137.5, 138. , 138.5, 139. ,
#        139.5, 140. , 140.5, 141. , 141.5, 142. , 142.5, 143. , 143.5,
#        144. , 144.5, 145. , 145.5, 146. , 146.5, 147. , 147.5, 148. ,
#        148.5, 149. , 149.5, 150. , 150.5, 151. , 151.5, 152. , 152.5,
#        153. , 153.5, 154. , 154.5, 155. , 155.5, 156. , 156.5, 157. ,
#        157.5, 158. , 158.5, 159. , 159.5, 160. , 160.5, 161. , 161.5,
#        162. , 162.5, 163. , 163.5, 164. , 164.5, 165. , 165.5, 166. ,
#        166.5, 167. , 167.5, 168. , 168.5, 169. , 169.5, 170. , 170.5,
#        171. , 171.5, 172. , 172.5, 173. , 173.5, 174. , 174.5, 175. ,
#        175.5, 176. , 176.5, 177. , 177.5, 178. , 178.5, 179. , 179.5,
#        180. ])

# %%
df = pd.DataFrame(columns = col_names)

# %%
df
# Out:
# Empty DataFrame
# Columns: [theta, s11, s12, s13, s14, s21, s22, s23, s24, s31, s32, s33, s34, s41, s42, s43, s44]
# Index: []

# %%
df['theta'] = cols[0]
df
# Out:
#      theta  s11  s12  s13  s14  s21  s22  s23  s24  s31  s32  s33  s34  s41  \
# 0      0.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      0.5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      1.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      1.5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      2.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 356  178.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 357  178.5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 358  179.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 359  179.5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 360  180.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      s42  s43  s44
# 0    NaN  NaN  NaN
# 1    NaN  NaN  NaN
# 2    NaN  NaN  NaN
# 3    NaN  NaN  NaN
# 4    NaN  NaN  NaN
# ..   ...  ...  ...
# 356  NaN  NaN  NaN
# 357  NaN  NaN  NaN
# 358  NaN  NaN  NaN
# 359  NaN  NaN  NaN
# 360  NaN  NaN  NaN
#
# [361 rows x 17 columns]

# %%
df['s11'] = cols[1]
df
# Out:
#      theta         s11  s12  s13  s14  s21  s22  s23  s24  s31  s32  s33  s34  \
# 0      0.0  612.349323  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      0.5  611.962044  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      1.0  610.801518  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      1.5  608.871664  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      2.0  606.178995  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..     ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 356  178.0   11.787434  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 357  178.5   11.854031  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 358  179.0   11.901923  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 359  179.5   11.930788  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 360  180.0   11.940431  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      s41  s42  s43  s44
# 0    NaN  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN
# 2    NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN
# ..   ...  ...  ...  ...
# 356  NaN  NaN  NaN  NaN
# 357  NaN  NaN  NaN  NaN
# 358  NaN  NaN  NaN  NaN
# 359  NaN  NaN  NaN  NaN
# 360  NaN  NaN  NaN  NaN
#
# [361 rows x 17 columns]

# %%
df['s12'] = cols[2]
df
# Out:
#      theta         s11           s12  s13  s14  s21  s22  s23  s24  s31  s32  \
# 0      0.0  612.349323  0.000000e+00  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      0.5  611.962044  1.676027e-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      1.0  610.801518  6.696991e-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      1.5  608.871664  1.504155e-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      2.0  606.178995  2.667423e-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..     ...         ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 356  178.0   11.787434  1.608229e-01  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 357  178.5   11.854031  9.082919e-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 358  179.0   11.901923  4.048512e-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 359  179.5   11.930788  1.013880e-02  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 360  180.0   11.940431  1.154632e-14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#      s33  s34  s41  s42  s43  s44
# 0    NaN  NaN  NaN  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN  NaN  NaN
# 2    NaN  NaN  NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN  NaN  NaN
# ..   ...  ...  ...  ...  ...  ...
# 356  NaN  NaN  NaN  NaN  NaN  NaN
# 357  NaN  NaN  NaN  NaN  NaN  NaN
# 358  NaN  NaN  NaN  NaN  NaN  NaN
# 359  NaN  NaN  NaN  NaN  NaN  NaN
# 360  NaN  NaN  NaN  NaN  NaN  NaN
#
# [361 rows x 17 columns]

# %%
df_s_d = df.iloc[:, 0:3]
df_s_d
# Out:
#      theta         s11           s12
# 0      0.0  612.349323  0.000000e+00
# 1      0.5  611.962044  1.676027e-02
# 2      1.0  610.801518  6.696991e-02
# 3      1.5  608.871664  1.504155e-01
# 4      2.0  606.178995  2.667423e-01
# ..     ...         ...           ...
# 356  178.0   11.787434  1.608229e-01
# 357  178.5   11.854031  9.082919e-02
# 358  179.0   11.901923  4.048512e-02
# 359  179.5   11.930788  1.013880e-02
# 360  180.0   11.940431  1.154632e-14
#
# [361 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

rad = np.linspace(0, 10, 361)
azm = np.linspace(0, 2 * np.pi, 361)
r, th = np.meshgrid(rad, azm)
z = -(r ** 2.0)

plt.subplot(projection="polar")

plt.grid()
plt.pcolormesh(th, r, z)
#plt.pcolormesh(th, z, r)

plt.plot(azm, r, color='k', ls='none') 

plt.show()

# %%
z.shape
# Out:
# (360, 361)

# %%
a = cols[0]
b= cols[1]

# %%
c = np.array((a,b.T))

# %%
c.shape
# Out:
# (2, 361)

# %%
from pylab import *
import numpy as np
from scipy.interpolate import griddata

#create 5000 Random points distributed within the circle radius 100
max_r = 100
max_theta = 2.0 * np.pi
number_points = 5000
points = np.random.rand(number_points,2)*[max_r,max_theta]

#Some function to generate values for these points, 
#this could be values = np.random.rand(number_points)
values = points[:,0] * np.sin(points[:,1])* np.cos(points[:,1])

#now we create a grid of values, interpolated from our random sample above
theta = np.linspace(0.0, max_theta, 100)
r = np.linspace(0, max_r, 200)
grid_r, grid_theta = np.meshgrid(r, theta)
data = griddata(points, values, (grid_r, grid_theta), method='cubic',fill_value=0)

#Create a polar projection
ax1 = plt.subplot(projection="polar")
ax1.pcolormesh(theta,r,data.T)
plt.show()
# Out:
# /tmp/ipykernel_9608/1939813956.py:23: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   ax1.pcolormesh(theta,r,data.T)

# %%
values.shape

# %%
min(points[:,1])

# %%
from pylab import *
import numpy as np
from scipy.ndimage import zoom
import pandas as pd

max_r = 100
max_theta = 2.5 * np.pi
number_points = 50

#Generate a grid 100 x 100 r x theta
r = np.arange(0, max_r,max_theta/number_points)
theta = np.arange(0,max_theta,max_theta/number_points)
grid_r, grid_theta = np.meshgrid(r, theta)

#Generate random numbers for each grid point
values = (np.sin(grid_r)+np.cos(grid_theta)).flatten()

#I always find it easier to put it in a dataframe
df = pd.DataFrame(grid_r.flatten()).rename(columns={0:'r'})
df['theta'] = grid_theta.flatten()
df['values'] = values
df = df.pivot(index='theta', columns='r')
#printing the dataframe at this point is very helpful conceptually

#Create a polar projection
ax1 = plt.subplot(projection="polar")
ax1.pcolormesh(df.index,r,df.values.T)
plt.show()

#Zoom in to the grid, this interpolates the results onto a finer grid
#Here I chose a 10x finer grid, this is more efficient than to interpolate onto specified points
zoom_factor=10

zoomed_df = zoom(df, zoom_factor)
zoomed_index = zoom(theta, zoom_factor)
zoomed_columns = zoom(r, zoom_factor)
high_def_grid = pd.DataFrame(zoomed_df, index=zoomed_index, columns=zoomed_columns)


#Create a polar projection
ax1 = plt.subplot(projection="polar")
ax1.pcolormesh(high_def_grid.index,high_def_grid.columns,high_def_grid.values.T)
plt.show()

# %%
df

# %%
import numpy as np
import matplotlib.pyplot as plt

#-- Generate Data -----------------------------------------
# Using linspace so that the endpoint of 360 is included...
azimuths = np.radians(np.linspace(0, 360, 20))
zeniths = cols[1]

r, theta = np.meshgrid(zeniths, azimuths)
values = np.random.random((azimuths.size, zeniths.size))

#-- Plot... ------------------------------------------------
fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
ax.contourf(theta, r, values)

plt.show()

# %%
values.shape
# Out:
# (20, 361)

# %%
cols[0]
# Out:
# array([  0. ,   0.5,   1. ,   1.5,   2. ,   2.5,   3. ,   3.5,   4. ,
#          4.5,   5. ,   5.5,   6. ,   6.5,   7. ,   7.5,   8. ,   8.5,
#          9. ,   9.5,  10. ,  10.5,  11. ,  11.5,  12. ,  12.5,  13. ,
#         13.5,  14. ,  14.5,  15. ,  15.5,  16. ,  16.5,  17. ,  17.5,
#         18. ,  18.5,  19. ,  19.5,  20. ,  20.5,  21. ,  21.5,  22. ,
#         22.5,  23. ,  23.5,  24. ,  24.5,  25. ,  25.5,  26. ,  26.5,
#         27. ,  27.5,  28. ,  28.5,  29. ,  29.5,  30. ,  30.5,  31. ,
#         31.5,  32. ,  32.5,  33. ,  33.5,  34. ,  34.5,  35. ,  35.5,
#         36. ,  36.5,  37. ,  37.5,  38. ,  38.5,  39. ,  39.5,  40. ,
#         40.5,  41. ,  41.5,  42. ,  42.5,  43. ,  43.5,  44. ,  44.5,
#         45. ,  45.5,  46. ,  46.5,  47. ,  47.5,  48. ,  48.5,  49. ,
#         49.5,  50. ,  50.5,  51. ,  51.5,  52. ,  52.5,  53. ,  53.5,
#         54. ,  54.5,  55. ,  55.5,  56. ,  56.5,  57. ,  57.5,  58. ,
#         58.5,  59. ,  59.5,  60. ,  60.5,  61. ,  61.5,  62. ,  62.5,
#         63. ,  63.5,  64. ,  64.5,  65. ,  65.5,  66. ,  66.5,  67. ,
#         67.5,  68. ,  68.5,  69. ,  69.5,  70. ,  70.5,  71. ,  71.5,
#         72. ,  72.5,  73. ,  73.5,  74. ,  74.5,  75. ,  75.5,  76. ,
#         76.5,  77. ,  77.5,  78. ,  78.5,  79. ,  79.5,  80. ,  80.5,
#         81. ,  81.5,  82. ,  82.5,  83. ,  83.5,  84. ,  84.5,  85. ,
#         85.5,  86. ,  86.5,  87. ,  87.5,  88. ,  88.5,  89. ,  89.5,
#         90. ,  90.5,  91. ,  91.5,  92. ,  92.5,  93. ,  93.5,  94. ,
#         94.5,  95. ,  95.5,  96. ,  96.5,  97. ,  97.5,  98. ,  98.5,
#         99. ,  99.5, 100. , 100.5, 101. , 101.5, 102. , 102.5, 103. ,
#        103.5, 104. , 104.5, 105. , 105.5, 106. , 106.5, 107. , 107.5,
#        108. , 108.5, 109. , 109.5, 110. , 110.5, 111. , 111.5, 112. ,
#        112.5, 113. , 113.5, 114. , 114.5, 115. , 115.5, 116. , 116.5,
#        117. , 117.5, 118. , 118.5, 119. , 119.5, 120. , 120.5, 121. ,
#        121.5, 122. , 122.5, 123. , 123.5, 124. , 124.5, 125. , 125.5,
#        126. , 126.5, 127. , 127.5, 128. , 128.5, 129. , 129.5, 130. ,
#        130.5, 131. , 131.5, 132. , 132.5, 133. , 133.5, 134. , 134.5,
#        135. , 135.5, 136. , 136.5, 137. , 137.5, 138. , 138.5, 139. ,
#        139.5, 140. , 140.5, 141. , 141.5, 142. , 142.5, 143. , 143.5,
#        144. , 144.5, 145. , 145.5, 146. , 146.5, 147. , 147.5, 148. ,
#        148.5, 149. , 149.5, 150. , 150.5, 151. , 151.5, 152. , 152.5,
#        153. , 153.5, 154. , 154.5, 155. , 155.5, 156. , 156.5, 157. ,
#        157.5, 158. , 158.5, 159. , 159.5, 160. , 160.5, 161. , 161.5,
#        162. , 162.5, 163. , 163.5, 164. , 164.5, 165. , 165.5, 166. ,
#        166.5, 167. , 167.5, 168. , 168.5, 169. , 169.5, 170. , 170.5,
#        171. , 171.5, 172. , 172.5, 173. , 173.5, 174. , 174.5, 175. ,
#        175.5, 176. , 176.5, 177. , 177.5, 178. , 178.5, 179. , 179.5,
#        180. ])

# %%
cols[1:].shape
# Out:
# (15, 361)
